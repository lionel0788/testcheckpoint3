# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Phase de Prétraitement

# %%
data=pd.read_csv('C:/Users/DELL/Desktop/GOMYCODE/titanic_passengers.csv', sep=';',)

# %%
data.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age']
# Out:
# 0      28.0
# 1      25.0
# 2      20.0
# 3      29.0
# 4      31.0
#        ...
# 886    14.0
# 887    22.0
# 888    30.0
# 889     NaN
# 890    19.0
# Name: Age, Length: 891, dtype: float64

# %%
data['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 80.00     1
# 36.50     1
# 55.50     1
# 14.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
data['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
data['Age'].dropna(axis=0)
# Out:
# 0      28.0
# 1      25.0
# 2      20.0
# 3      29.0
# 4      31.0
#        ...
# 885    42.0
# 886    14.0
# 887    22.0
# 888    30.0
# 890    19.0
# Name: Age, Length: 714, dtype: float64

# %%
data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False   True  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
data['PassengerId'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: PassengerId, Length: 891, dtype: bool

# %%
data['Survived'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
data['Cabin'].dropna(axis=0)
# Out:
# 1      F G73
# 4        B71
# 16       C82
# 19       C93
# 26       B41
#        ...
# 862       F4
# 863      E17
# 865      B80
# 875      E63
# 881      C68
# Name: Cabin, Length: 204, dtype: object

# %%
data['Embarked'].dropna(axis=0)
# Out:
# 0      S
# 1      S
# 2      S
# 3      S
# 4      S
#       ..
# 886    C
# 887    C
# 888    S
# 889    S
# 890    S
# Name: Embarked, Length: 889, dtype: object

# %%
data.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
data=pd.read_csv('C:/Users/DELL/Desktop/GOMYCODE/titanic_passengers.csv', sep=';',)

# %%
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=data['Age'].mean()

# %%
df=30.0

# %%
df
# Out:
# 30.0

# %%
data['Age'].fillna(df)
# Out:
# 0      28.0
# 1      25.0
# 2      20.0
# 3      29.0
# 4      31.0
#        ...
# 886    14.0
# 887    22.0
# 888    30.0
# 889    30.0
# 890    19.0
# Name: Age, Length: 891, dtype: float64

# %%
data['Cabin'].value_counts()
# Out:
# B96 B98        4
# C23 C25 C27    4
# G6             4
# D              3
# F2             3
#               ..
# C50            1
# A24            1
# B38            1
# C148           1
# B82 B84        1
# Name: Cabin, Length: 147, dtype: int64

# %%
data['Cabin'].fillna('G6')
# Out:
# 0         G6
# 1      F G73
# 2         G6
# 3         G6
# 4        B71
#        ...
# 886       G6
# 887       G6
# 888       G6
# 889       G6
# 890       G6
# Name: Cabin, Length: 891, dtype: object

# %%
data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data['Embarked'].fillna('S')
# Out:
# 0      S
# 1      S
# 2      S
# 3      S
# 4      S
#       ..
# 886    C
# 887    C
# 888    S
# 889    S
# 890    S
# Name: Embarked, Length: 891, dtype: object

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# # Phase de Visualisation des données

# %%
data
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Cabin'].fillna('G6',inplace=True)

# %%
data.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000     G6        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542     G6        S
# 3  female  29.0      0      4      349909  21.0750     G6        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
data['Embarked'].fillna('S',inplace=True)

# %%
data['Embarked'].isnull().sum()
# Out:
# 0

# %%
data['Age'].fillna(df,inplace=True)

# %%
data['Age'].isnull().sum()
# Out:
# 0

# %%
data['Sex'].isnull().sum()
# Out:
# 0

# %%
data.select_dtypes('object')
# Out:
#     Survived                                               Name     Sex  \
# 0         No                         Collander, Mr. Erik Gustaf    male
# 1         No                            Moen, Mr. Sigurd Hansen    male
# 2         No                             Jensen, Mr. Hans Peder    male
# 3         No        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female
# 4         No                             Davidson, Mr. Thornton    male
# ..       ...                                                ...     ...
# 886      Yes                Nasser, Mrs. Nicholas (Adele Achem)  female
# 887       No                              Sirayanian, Mr. Orsen    male
# 888       No                                Cacic, Miss. Marija  female
# 889       No                   Petroff, Mr. Pastcho ("Pentcho")    male
# 890      Yes  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female
#
#          Ticket  Cabin Embarked
# 0        248740     G6        S
# 1        348123  F G73        S
# ...

# %% [markdown]
# # Commençons la phase de visualisation

# %%
#Commencez par étudier la distribution des caractéristiques les plus importantes en fonction de votre compréhension de l'ensemble de données et du problème.

# %% [markdown]
# # Checklist de base

# %%
#Analyse de forme:
#variable target:Survived
#lignes et colonnes:(891, 12)
#types de variables:int64,object,float64

#Analyse de fond:
#visualisation de la target:+60% n'ont pas survécu.
#-40% ont survécu. 
#signification des variables:variables float standardisés.
#variables qualitatives non toutes binaires,variables nom un peu 
#inutile, les variables qualitatives utiles sont:
#Survived,Embarked.
#Relation Variables/Target:
#81 femmes n'ont pas survécu tandis que 233 ont survécu.
#468 hommes n'ont pas survécu et 109 ont survécu.

# %% [markdown]
# # Analyse de la forme

# %%
data.shape
# Out:
# (891, 12)

# %%
data.dtypes.value_counts()
# Out:
# object     6
# int64      4
# float64    2
# dtype: int64

# %% [markdown]
# # Examen de la colonne Target

# %%
data['Survived'].value_counts()
# Out:
# No     549
# Yes    342
# Name: Survived, dtype: int64

# %%
data['Survived'].value_counts(normalize=True)
# Out:
# No     0.616162
# Yes    0.383838
# Name: Survived, dtype: float64

# %% [markdown]
# # Histogrammes des variables continues

# %%
for col in data.select_dtypes('float'):
    plt.figure()
    sns.distplot(data[col])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Visualisation des variables catégorielles ou qualitatives

# %%
for col in data.select_dtypes('object'):
    plt.figure()
    data[col].value_counts().plot.pie()

# %% [markdown]
# # Relation Variables/Target

# %%
data[data['Sex']=='male']
# Out:
#      PassengerId Survived  Pclass                               Name   Sex  \
# 0            343       No       2         Collander, Mr. Erik Gustaf  male
# 1             76       No       3            Moen, Mr. Sigurd Hansen  male
# 2            641       No       3             Jensen, Mr. Hans Peder  male
# 4            672       No       1             Davidson, Mr. Thornton  male
# 5            105       No       3     Gustafsson, Mr. Anders Vilhelm  male
# ..           ...      ...     ...                                ...   ...
# 883          809       No       2                  Meyer, Mr. August  male
# 884          278       No       2        Parkes, Mr. Francis "Frank"  male
# 885          150       No       2  Byles, Rev. Thomas Roussel Davids  male
# 887           61       No       3              Sirayanian, Mr. Orsen  male
# 889          102       No       3   Petroff, Mr. Pastcho ("Pentcho")  male
#
#       Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# ...

# %%
data[data['Sex']=='female']
# Out:
#      PassengerId Survived  Pclass  \
# 3            568       No       3
# 7            382      Yes       3
# 9            433      Yes       2
# 11           294       No       3
# 12           755      Yes       2
# ..           ...      ...     ...
# 880          360      Yes       3
# 882          775      Yes       2
# 886           10      Yes       2
# 888          535       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 7                          Nakid, Miss. Maria ("Mary")  female   1.0      0
# 9    Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
# 11                                 Haas, Miss. Aloisia  female  24.0      0
# 12                    Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Target/Age

# %%
pd.crosstab(data['Sex'],data['Survived'])
# Out:
# Survived   No  Yes
# Sex
# female     81  233
# male      468  109

# %%
sns.heatmap(pd.crosstab(data['Survived'],data['Sex']),annot=True,fmt='d')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
#Visualisez la corrélation entre le sexe et l'âge dans un graphique de votre choix.
#L'intrigue visualisée devrait nous donner des déductions évidentes concernant l'importance de l'âge et du sexe 
#dans la survie des individus

# %% [markdown]
# # Encodage de la variable Sex

# %%
code={"Sex":{"male":1,"female":0}}
data.replace(code,inplace=True)

# %% [markdown]
# # Tableau de corrélation Age/Sex

# %%
plt.hist2d(data['Sex'],data['Age'])
plt.colorbar()

# %%
#Pick two other features and study their impact on the survival of the individuals.

# %%
sns.heatmap(pd.crosstab(data['PassengerId'],data['Pclass']),annot=True,fmt='d')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='PassengerId'>

# %%
#Voyons la corrélation entre la Pclass et Sibsp dans la survie des individus

# %%
df1=data.drop(['PassengerId','Sex','Age','Name','Pclass','Ticket','Fare','Cabin','Embarked'],axis=1)

# %%
df1.head()
# Out:
#   Survived  SibSp  Parch
# 0       No      0      0
# 1       No      0      0
# 2       No      0      0
# 3       No      0      4
# 4       No      1      0

# %%
plt.scatter(df1['SibSp'],df1['Parch'],c='g')

# %%
df1.corr()
# Out:
#           SibSp     Parch
# SibSp  1.000000  0.414838
# Parch  0.414838  1.000000

# %% [markdown]
# # Fonction

# %%
#Jetez un oeil à cette fonction:

#def plot_correlation_map( df ):

 #   corr = df.corr()

 #   s , ax = plt.subplots( figsize =( 12 , 10 ) )

#    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

 #   s = sns.heatmap(

#        corr, 

 #       cmap = cmap,

 #       square=True, 

  #      cbar_kws={ 'shrink' : .9 }, 

 #       ax=ax, 

 #       annot = True, 

#        annot_kws = { 'fontsize' : 12 }

#        )
#
#Essayez d'exécuter la fonction, analysez ce qu'elle fait exactement et ses utilités et enfin, écrivez un paragraphe décrivant votre analyse (le paragraphe doit être en anglais).

#Utilisez la fonction groupby combinée avec la moyenne () pour afficher la relation entre Pclass et survived 

#Dans une dernière étape, essayez de supprimer les colonnes inutiles telles que les noms

#En fait, nous avons supprimé la colonne Names car nous l'avons jugée inutile. Eh bien, ce n'est pas le cas car nous pouvons créer une fonctionnalité très utile à partir des noms.

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map( data)

# %%
# analyse de la fonction et ses utilités:
#l'on remarque qu'il y a 100% de corrélation entre les variables qui se ressemblent.
#il y a aussi une corrélation de 41% entre le Parch et le SibSp,les autres corrélations sont faibles(-25% de corrélation)
#Traduction en anglais
#These data represent the different correlations between the data in the dataset.
#These correlations are explained by percentages.
#The colors therefore identify the level of correlation based on the percentage.

# %%
data.groupby(['Pclass','Survived']).mean()
# Out:
#                  PassengerId       Sex        Age     SibSp     Parch  \
# Pclass Survived
# 1      No         410.300000  0.962500  40.956250  0.287500  0.300000
#        Yes        491.772059  0.330882  34.815588  0.492647  0.389706
# 2      No         452.123711  0.938144  33.288660  0.319588  0.144330
#        Yes        439.080460  0.195402  26.090000  0.494253  0.643678
# 3      No         453.580645  0.806452  27.500000  0.672043  0.384409
#        Yes        394.058824  0.394958  23.318655  0.436975  0.420168
#
#                       Fare
# Pclass Survived
# 1      No        64.684008
#        Yes       95.608029
# 2      No        19.412328
#        Yes       22.055700
# 3      No        13.669364
#        Yes       13.694887

# %%
data.drop(['Name'],axis=1)
# Out:
#      PassengerId Survived  Pclass  Sex   Age  SibSp  Parch      Ticket  \
# 0            343       No       2    1  28.0      0      0      248740
# 1             76       No       3    1  25.0      0      0      348123
# 2            641       No       3    1  20.0      0      0      350050
# 3            568       No       3    0  29.0      0      4      349909
# 4            672       No       1    1  31.0      1      0  F.C. 12750
# ..           ...      ...     ...  ...   ...    ...    ...         ...
# 886           10      Yes       2    0  14.0      1      0      237736
# 887           61       No       3    1  22.0      0      0        2669
# 888          535       No       3    0  30.0      0      0      315084
# 889          102       No       3    1  30.0      0      0      349215
# 890          428      Yes       2    0  19.0      0      0      250655
#
#         Fare  Cabin Embarked
# 0    13.0000     G6        S
# 1     7.6500  F G73        S
# ...

# %%
def title():
    liste=[]
    for i in data['Name']:
        cpte=0
        x=i.split(",")
        x=x[1]
        x=x.split(".")
        x=x[0]+","
        liste=x.split(",")
        print(liste)

# %%
title()
# Out:
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mrs', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Miss', '']
# [' Mr', '']
# [' Mrs', '']
# [' Mr', '']
# [' Miss', '']
# [' Mrs', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Miss', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mrs', '']
# [' Mr', '']
# [' Mr', '']
# [' Dr', '']
# [' Mr', '']
# [' Miss', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Major', '']
# [' Mrs', '']
# [' Don', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Miss', '']
# [' Miss', '']
# [' Mr', '']
# [' Mr', '']
# [' Miss', '']
# [' Mr', '']
# [' Miss', '']
# [' Mr', '']
# [' Master', '']
# [' Dr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mrs', '']
# [' Mrs', '']
# [' Miss', '']
# [' Miss', '']
# [' Master', '']
# [' Miss', '']
# [' Mr', '']
# [' Rev', '']
# ...

# %%
data.loc[:,'Titre']=title()
# Out:
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mrs', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Miss', '']
# [' Mr', '']
# [' Mrs', '']
# [' Mr', '']
# [' Miss', '']
# [' Mrs', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Miss', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mrs', '']
# [' Mr', '']
# [' Mr', '']
# [' Dr', '']
# [' Mr', '']
# [' Miss', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Major', '']
# [' Mrs', '']
# [' Don', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Miss', '']
# [' Miss', '']
# [' Mr', '']
# [' Mr', '']
# [' Miss', '']
# [' Mr', '']
# [' Miss', '']
# [' Mr', '']
# [' Master', '']
# [' Dr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mr', '']
# [' Mrs', '']
# [' Mrs', '']
# [' Miss', '']
# [' Miss', '']
# [' Master', '']
# [' Miss', '']
# [' Mr', '']
# [' Rev', '']
# ...

# %%
#Visualisez la corrélation entre le titre et d'autres caractéristiques (par exemple, le sexe, le tarif, l'âge...)

# %%
#Comme vous l'avez vu, il existe de nombreux titres qui rendent la fonctionnalité très peu pratique, essayons de regrouper ces titres en titres plus utiles.

#indice : utilisez le dictionnaire suivant

#Titre_Dictionnaire = {

     #               "Capt": "Officier",

     #               "Col": "Officier",

    #                "Major": "Officier",

    #                  "Dr": "Officier",

    #                "Rév": "Officier",

    #                "Jonkheer": "Redevance",

    #                "Don": "Redevance",

    #                "Monsieur" : "Royauté",

    #               "Dame" : "Royauté"

    #              "la Comtesse": "Royauté",

   #                 "Dona": "Royauté",

   #                 "Mme": "Madame",

  #                  "Mlle": "Madame",

  #                  "Madame" : "Madame",

 #                   "Mlle Mme",

  #                  "Monsieur Madame",

 #                   "Mme" : "Mme

 #                   "Maître" : "Maître"

 #                   }

#visualisons maintenant les mêmes corrélations en utilisant ces nouveaux titres.

# %%
Title_Dictionary = {

                    'Capt':'Officer',

                    'Col':'Officer',

                    'Major':'Officer',

                      'Dr':'Officer',

                    'Rev':'Officer',

                    'Jonkheer':"Royalty",

                    'Don':'Royalty',

                    'Sir' :'Royalty',

                   'Lady' :'Royalty',

                   'countess':'Royalty',

                    'Dona':'Royalty',

                    'Mme':'Miss',

                    'Mlle':'Miss',

                    'Miss' :'Miss',

                    'Ms':'Mrs',

                    'Mr' :'Mrs',

                    'Mrs' :'Mrs',

                    'Master' :'Master'

}

# %%
# Enfin, utilisez les colonnes Parch et SibSp pour créer une fonctionnalité plus utile, appelons-la FamilySize.
#Utilisez ce que vous avez appris jusqu'à présent pour déterminer si cette fonctionnalité est utile ou non.

# %%
#sibsp - Nombre de frères et sœurs/conjoints à bord
#parch - Nombre de Billet Parents/Enfants à bord

# %%
familysize=data['SibSp']+data['Parch']

# %%
data.loc[:,'Familysize']=familysize

# %%
data.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked Titre  \
# 0    1  28.0      0      0      248740  13.0000     G6        S  None
# 1    1  25.0      0      0      348123   7.6500  F G73        S  None
# 2    1  20.0      0      0      350050   7.8542     G6        S  None
# 3    0  29.0      0      4      349909  21.0750     G6        S  None
# 4    1  31.0      1      0  F.C. 12750  52.0000    B71        S  None
#
#    Familysize
# 0           0
# 1           0
# 2           0
# 3           4
# ...

# %%
data['Familysize'].value_counts()
# Out:
# 0     537
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: Familysize, dtype: int64

# %%
df2=data.drop(['PassengerId','Sex','Age','Name','Pclass','Ticket','Fare','Cabin','Embarked','Titre'],axis=1)

# %%
df2
# Out:
#     Survived  SibSp  Parch  Familysize
# 0         No      0      0           0
# 1         No      0      0           0
# 2         No      0      0           0
# 3         No      0      4           4
# 4         No      1      0           1
# ..       ...    ...    ...         ...
# 886      Yes      1      0           1
# 887       No      0      0           0
# 888       No      0      0           0
# 889       No      0      0           0
# 890      Yes      0      0           0
#
# [891 rows x 4 columns]

# %%
plot_correlation_map( data)

# %%
data.corr()
# Out:
#              PassengerId    Pclass       Sex       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.035144  0.042939  0.033019 -0.057527 -0.001652
# Pclass         -0.035144  1.000000  0.131900 -0.329727  0.083081  0.018443
# Sex             0.042939  0.131900  1.000000  0.084660 -0.114631 -0.245489
# Age             0.033019 -0.329727  0.084660  1.000000 -0.232440 -0.180330
# SibSp          -0.057527  0.083081 -0.114631 -0.232440  1.000000  0.414838
# Parch          -0.001652  0.018443 -0.245489 -0.180330  0.414838  1.000000
# Fare            0.012658 -0.549500 -0.182333  0.090632  0.159651  0.216225
# Familysize     -0.040143  0.065997 -0.200988 -0.248954  0.890712  0.783111
#
#                  Fare  Familysize
# PassengerId  0.012658   -0.040143
# Pclass      -0.549500    0.065997
# Sex         -0.182333   -0.200988
# Age          0.090632   -0.248954
# SibSp        0.159651    0.890712
# Parch        0.216225    0.783111
# Fare         1.000000    0.217138
# ...

# %%
plt.scatter(data['Familysize'],data['Fare'],c='y')
